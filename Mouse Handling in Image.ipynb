# %%
import cv2

def mouse_event(event,x,y,flag, param):
    if(event==cv2.EVENT_LBUTTONDOWN):
        
        cv2.putText(image,"Mouse",(x,y),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),5)
        cv2.imshow("frame",image)

image=cv2.imread("17.jpg")

cv2.imshow("Image",image)
cv2.setMouseCallback("Image", mouse_event)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
# knowing the coordinate where mouse is pressed

import cv2

def mouse_event(event,x,y,flag, param):
    if(event==cv2.EVENT_LBUTTONDOWN):
        str1=str(x)+","+str(y)
        
        cv2.putText(image,str1,(x,y),
                    cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),5)
        cv2.imshow("frame",image)

image=cv2.imread("17.jpg")

cv2.imshow("frame",image)
cv2.setMouseCallback("frame", mouse_event)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# knowing the coordinate where mouse is pressed

import cv2

def mouse_event(event,x,y,flag, param):
    if(event==cv2.EVENT_LBUTTONDOWN):
        points.append((x,y))
        if len(points)==2:
            cv2.rectangle(image,points[0],points[1],(0,255,0),3)
        
        
    cv2.imshow("frame",image)

image=cv2.imread("17.jpg")
points=[]

cv2.imshow("frame",image)
cv2.setMouseCallback("frame", mouse_event)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# draw the line  where mouse is moved in the figure

import cv2

def mouse_event(event,x,y,flag, param):
    if(event==cv2.EVENT_LBUTTONDOWN):
        points.append((x,y))
        if len(points)==2:
            cv2.rectangle(image,points[0],points[1],(0,255,0),3)
            
    if(event==cv2.EVENT_MOUSEMOVE):
        points.append((x,y))
        if (len(points)>=2):
            cv2.line(image,points[-2],points[-1],(56,255,100),3)
        
        
    cv2.imshow("frame",image)

image=cv2.imread("17.jpg")
points=[]

cv2.imshow("frame",image)
cv2.setMouseCallback("frame", mouse_event)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

def mouse_event(event,x,y,flag, param):
    if(event==cv2.EVENT_LBUTTONDOWN):
        points.append((x,y))
        if len(points)==2:
            cv2.rectangle(image,points[0],points[1],(0,255,0),3)
            
    if(event==cv2.EVENT_MOUSEMOVE):
        points.append((x,y))
        if (len(points)>=2):
            cv2.line(image,points[-2],points[-1],(56,255,100),3)
            
    if(event==cv2.EVENT_RBUTTONDOWN):
        blue=image[y,x,0]
        green=image[y,x,1]
        red=image[y,x,2]
        str1=str(blue)+","+str(green)+","+str(red)
        cv2.putText(image,str1,(x,y),cv2.FONT_HERSHEY_SIMPLEX,.5,(0,0,255),2)
        
        
        
    cv2.imshow("frame",image)

image=cv2.imread("17.jpg")
points=[]

cv2.imshow("frame",image)
cv2.setMouseCallback("frame", mouse_event)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#cropping the images

import numpy as np
import cv2

def mouse_event(event,x,y,flag, param):
    if(event==cv2.EVENT_LBUTTONDOWN):
        points.append((x,y))
        if len(points)==2:
            cv2.rectangle(image,points[0],points[1],(0,255,0),3)
            
            crop_image=image[points[-2][1]:points[-1][1],points[-2][0]:points[-1][0]]
            cv2.imshow("frame1",crop_image)
            
        
        
    cv2.imshow("frame",image)

image=cv2.imread("17.jpg")
points=[]

cv2.imshow("frame",image)
cv2.setMouseCallback("frame", mouse_event)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-41-8993fc88f890> in mouse_event(event, x, y, flag, param)
#      11
#      12             crop_image=image[points[-2][1]:points[-1][1],points[-2][0]:points[-1][0]]
# ---> 13             cv2.imshow("frame1",crop_image)
#      14
#      15
#
# error: OpenCV(4.0.1) C:\ci\opencv-suite_1573470242804\work\modules\highgui\src\window.cpp:352: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
